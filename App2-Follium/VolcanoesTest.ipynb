# %%
import pandas

# %%
data = pandas.read_csv("Volcanoes.txt")

# %%
data
# Out:
#     VOLCANX020    NUMBER            NAME       LOCATION  \
# 0        509.0  1201-01=           Baker  US-Washington
# 1        511.0  1201-02-    Glacier Peak  US-Washington
# 2        513.0  1201-03-         Rainier  US-Washington
# 3        515.0  1201-05-      St. Helens  US-Washington
# 4        516.0  1201-04-           Adams  US-Washington
# ..         ...       ...             ...            ...
# 57       580.0  1210-03-  Valles Caldera  US-New Mexico
# 58       581.0  1209-02-   Sunset Crater     US-Arizona
# 59       584.0  1203-20-           Amboy  US-California
# 60       586.0  1210-02-    Zuni-Bandera  US-New Mexico
# 61       588.0  1210-01-       Carrizozo  US-New Mexico
#
#                    STATUS    ELEV             TYPE TIMEFRAME        LAT  \
# 0              Historical  3285.0  Stratovolcanoes        D3  48.776798
# 1        Tephrochronology  3213.0    Stratovolcano        D4  48.111801
# 2        Dendrochronology  4392.0    Stratovolcano        D3  46.869801
# ...

# %%
nameList = data["NAME"]

# %%
WritingList = data["LOCATION"]+ " "  + data["NAME"]+ " " + data["STATUS"]+ " " + data["TYPE"]

# %%
WritingList
# Out:
# 0        US-Washington Baker Historical Stratovolcanoes
# 1     US-Washington Glacier Peak Tephrochronology St...
# 2     US-Washington Rainier Dendrochronology Stratov...
# 3     US-Washington St. Helens Historical Stratovolcano
# 4     US-Washington Adams Tephrochronology Stratovol...
#                             ...
# 57    US-New Mexico Valles Caldera Pleistocene-Fumar...
# 58    US-Arizona Sunset Crater Dendrochronology Cind...
# 59             US-California Amboy Holocene Cinder cone
# 60    US-New Mexico Zuni-Bandera Anthropology Volcan...
# 61         US-New Mexico Carrizozo Holocene Cinder cone
# Length: 62, dtype: object

# %%
data[data.columns[1]
# Out:
#   File "<ipython-input-18-4ac8e508208e>", line 1
#     data[data.columns[1]
#                         ^
# SyntaxError: unexpected EOF while parsing
